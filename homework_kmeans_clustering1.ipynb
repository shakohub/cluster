# %%
from sklearn.cluster import KMeans

import pandas as pd
import seaborn as sns

from matplotlib import pyplot as plt

# %matplotlib inline

# %%
# read file into dataframe
filepath = "credit_card3.csv"

df = pd.read_csv(filepath)
df.head()
# Out:
#   CUST_ID      BALANCE  PURCHASES_FREQUENCY  CREDIT_LIMIT  MINIMUM_PAYMENTS  \
# 0  C10001    40.900749             0.166667        1000.0        139.509787
# 1  C10002  3202.467416             0.000000        7000.0       1072.340217
# 2  C10003  2495.148862             1.000000        7500.0        627.284787
# 3  C10004  1666.670542             0.083333        7500.0               NaN
# 4  C10005   817.714335             0.083333        1200.0        244.791237
#
#    Purchase Score
# 0         16.6667
# 1          0.0000
# 2        100.0000
# 3          8.3333
# 4          8.3333

# %%
df=df.drop(['PURCHASES_FREQUENCY'],axis=1)

# %%
df.head()
# Out:
#   CUST_ID      BALANCE  CREDIT_LIMIT  MINIMUM_PAYMENTS  Purchase Score
# 0  C10001    40.900749        1000.0        139.509787         16.6667
# 1  C10002  3202.467416        7000.0       1072.340217          0.0000
# 2  C10003  2495.148862        7500.0        627.284787        100.0000
# 3  C10004  1666.670542        7500.0               NaN          8.3333
# 4  C10005   817.714335        1200.0        244.791237          8.3333

# %%
df=df.drop(['CUST_ID'],axis=1)

# %%
df.head()
# Out:
#        BALANCE  CREDIT_LIMIT  MINIMUM_PAYMENTS  Purchase Score
# 0    40.900749        1000.0        139.509787         16.6667
# 1  3202.467416        7000.0       1072.340217          0.0000
# 2  2495.148862        7500.0        627.284787        100.0000
# 3  1666.670542        7500.0               NaN          8.3333
# 4   817.714335        1200.0        244.791237          8.3333

# %%
df['MINIMUM_PAYMENTS'].describe()
# Out:
# count     8637.000000
# mean       864.206542
# std       2372.446607
# min          0.019163
# 25%        169.123707
# 50%        312.343947
# 75%        825.485459
# max      76406.207520
# Name: MINIMUM_PAYMENTS, dtype: float64

# %%
df.describe()
# Out:
#             BALANCE  CREDIT_LIMIT  MINIMUM_PAYMENTS  Purchase Score
# count   8950.000000   8949.000000       8637.000000     8950.000000
# mean    1564.474828   4494.449450        864.206542       49.035055
# std     2081.531879   3638.815725       2372.446607       40.137075
# min        0.000000     50.000000          0.019163        0.000000
# 25%      128.281915   1600.000000        169.123707        8.333300
# 50%      873.385231   3000.000000        312.343947       50.000000
# 75%     2054.140036   6500.000000        825.485459       91.666700
# max    19043.138560  30000.000000      76406.207520      100.000000

# %%
df.isnull().sum()
# Out:
# BALANCE               0
# CREDIT_LIMIT          1
# MINIMUM_PAYMENTS    313
# Purchase Score        0
# dtype: int64

# %%
#filling missing values with mean ones
df['CREDIT_LIMIT'].fillna(df['CREDIT_LIMIT'].mean(),inplace=True)

# %%
#filling missing values with mean ones
df['MINIMUM_PAYMENTS'].fillna(df['MINIMUM_PAYMENTS'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# BALANCE             0
# CREDIT_LIMIT        0
# MINIMUM_PAYMENTS    0
# Purchase Score      0
# dtype: int64

# %%
# rename column headers
colheader = {'BALANCE': 'BALANCE',
             'MINIMUM_PAYMENTS':'PAYMENTS', 
             'CREDIT_LIMIT':'LIMIT',
             'Purchase Score':'Score'}

df.rename(columns=colheader, inplace=True)

# %%
df.head()
# Out:
#        BALANCE   LIMIT     PAYMENTS     Score
# 0    40.900749  1000.0   139.509787   16.6667
# 1  3202.467416  7000.0  1072.340217    0.0000
# 2  2495.148862  7500.0   627.284787  100.0000
# 3  1666.670542  7500.0   864.206542    8.3333
# 4   817.714335  1200.0   244.791237    8.3333

# %%
sns.distplot(df['Score'])

# %%
sns.distplot(df['LIMIT'])

# %%
sns.distplot(df['PAYMENTS'])

# %%
sns.distplot(df['BALANCE'])

# %%
# function to assign age groups
def BALANCE_groups(BALANCE):
    if BALANCE <= 5000:
        group = '0-5000'
    elif BALANCE <= 10000:
        group = '5001-10000'
    elif BALANCE < 15000:
        group = '10001-14999'
    elif BALANCE >= 15001:
        group = '15001+'
        
    return group

# %%
df['BALANCE_groups'] = df['BALANCE'].apply(BALANCE_groups)

# %%
def LIMIT_groups(LIMIT):
    if LIMIT < 5000:
        group = '0- $5K'
    elif LIMIT < 15000:
        group = '$5-15K'
    elif LIMIT < 20000:
        group = '$15-20K'
    elif LIMIT >= 20000:
        group = '$20K+'
        
    return group

# %%
df['LIMIT_groups'] = df['LIMIT'].apply(LIMIT_groups)

# %%
def PAYMENTS_groups(PAYMENTS):
    if PAYMENTS <= 200:
        group = '0-$200'
    elif PAYMENTS <= 500:
        group = '$201-$500'
    elif PAYMENTS < 600:
        group = '$501-$599'
    elif PAYMENTS >= 600:
        group = '$600+'
        
    return group

# %%
df['PAYMENTS_groups'] = df['PAYMENTS'].apply(PAYMENTS_groups)

# %%
df.head()
# Out:
#        BALANCE   LIMIT     PAYMENTS     Score BALANCE_groups LIMIT_groups  \
# 0    40.900749  1000.0   139.509787   16.6667         0-5000       0- $5K
# 1  3202.467416  7000.0  1072.340217    0.0000         0-5000       $5-15K
# 2  2495.148862  7500.0   627.284787  100.0000         0-5000       $5-15K
# 3  1666.670542  7500.0   864.206542    8.3333         0-5000       $5-15K
# 4   817.714335  1200.0   244.791237    8.3333         0-5000       0- $5K
#
#   PAYMENTS_groups
# 0          0-$200
# 1           $600+
# 2           $600+
# 3           $600+
# 4       $201-$500

# %%
pd.pivot_table(data= df, index=['LIMIT'], values=['Score'])
# Out:
#              Score
# LIMIT
# 50.0       0.00000
# 150.0      3.63636
# 200.0     11.11110
# 300.0     29.28880
# 400.0     47.22220
# ...            ...
# 22500.0  100.00000
# 23000.0   33.33335
# 25000.0  100.00000
# 28000.0   90.00000
# 30000.0   64.16665
#
# [206 rows x 1 columns]

# %%
sns.pairplot(data=df, hue="LIMIT_groups")

# %%
sns.pairplot(data=df, hue="BALANCE_groups")

# %%
X = df[['BALANCE', 'PAYMENTS','LIMIT', 'Score']]
X.head()
# Out:
#        BALANCE     PAYMENTS   LIMIT     Score
# 0    40.900749   139.509787  1000.0   16.6667
# 1  3202.467416  1072.340217  7000.0    0.0000
# 2  2495.148862   627.284787  7500.0  100.0000
# 3  1666.670542   864.206542  7500.0    8.3333
# 4   817.714335   244.791237  1200.0    8.3333

# %%
kmeans = KMeans(n_clusters=5)

# %%
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.cluster_centers_
# Out:
# array([[ 1309.62594295,   458.29668714, 11926.96078431,    63.61125147],
#        [ 1978.29978803,   780.28043166,  6232.60406944,    53.19661943],
#        [ 4489.64931388, 22662.37664707,  4715.51724138,    48.95506552],
#        [ 7537.65133459,  2667.24564821, 11514.86988848,    47.15927732],
#        [  766.4862575 ,   528.50803199,  2125.70787105,    45.6357267 ]])

# %%
df['cluster'] = kmeans.labels_
df.head()
# Out:
#        BALANCE   LIMIT     PAYMENTS     Score BALANCE_groups LIMIT_groups  \
# 0    40.900749  1000.0   139.509787   16.6667         0-5000       0- $5K
# 1  3202.467416  7000.0  1072.340217    0.0000         0-5000       $5-15K
# 2  2495.148862  7500.0   627.284787  100.0000         0-5000       $5-15K
# 3  1666.670542  7500.0   864.206542    8.3333         0-5000       $5-15K
# 4   817.714335  1200.0   244.791237    8.3333         0-5000       0- $5K
#
#   PAYMENTS_groups  cluster
# 0          0-$200        4
# 1           $600+        1
# 2           $600+        1
# 3           $600+        1
# 4       $201-$500        4

# %%
sns.pairplot(data=df, hue='cluster')
# Out:
# C:\Users\MR_SA\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\MR_SA\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# C:\Users\MR_SA\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\MR_SA\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# C:\Users\MR_SA\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\MR_SA\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# C:\Users\MR_SA\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\MR_SA\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# C:\Users\MR_SA\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\MR_SA\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
# compare "Income" and "Score"
sns.scatterplot(data=df, x='LIMIT', y='Score', hue='cluster')

# scatterplot of centroid coordinates for income and spending score
plt.scatter(kmeans.cluster_centers_[:, 1], kmeans.cluster_centers_[:, 2], c='red', marker='x')

plt.title("LIMIT and Spending Score Groups")
#put the legend on the right
plt.legend(bbox_to_anchor=(1,1), loc=2)

# %%
# compare "Income" and "Score"
sns.scatterplot(data=df, x='BALANCE', y='Score', hue='cluster')

# scatterplot of centroid coordinates for income and spending score
plt.scatter(kmeans.cluster_centers_[:, 1], kmeans.cluster_centers_[:, 2], c='red', marker='x')

plt.title("BALANCE and Spending Score Groups")
#put the legend on the right
plt.legend(bbox_to_anchor=(1,1), loc=2)

# %%
# compare "Income" and "Score"
sns.scatterplot(data=df, x='PAYMENTS', y='Score', hue='cluster')

# scatterplot of centroid coordinates for income and spending score
plt.scatter(kmeans.cluster_centers_[:, 1], kmeans.cluster_centers_[:, 2], c='red', marker='x')

plt.title("PAYMENTS and Spending Score Groups")
#put the legend on the right
plt.legend(bbox_to_anchor=(1,1), loc=2)

# %%
cluster = df.loc[df['cluster'] == 0]
cluster.head()
# Out:
#         BALANCE    LIMIT    PAYMENTS     Score BALANCE_groups LIMIT_groups  \
# 6    627.260806  13500.0  198.065894  100.0000         0-5000       $5-15K
# 9    152.225975  11000.0  100.302262   16.6667         0-5000       $5-15K
# 18  1989.072228  13000.0  744.613395   66.6667         0-5000       $5-15K
# 76  1727.638449  11000.0  623.656993  100.0000         0-5000       $5-15K
# 81    81.584711   9500.0  164.692136    0.0000         0-5000       $5-15K
#
#    PAYMENTS_groups  cluster
# 6           0-$200        0
# 9           0-$200        0
# 18           $600+        0
# 76           $600+        0
# 81          0-$200        0

# %%
len(cluster)
# Out:
# 611

# %%
cluster.describe()
# Out:
#            BALANCE         LIMIT     PAYMENTS       Score  cluster
# count   611.000000    611.000000   611.000000  611.000000    611.0
# mean   1309.923786  11931.751227   458.572528   63.551695      0.0
# std    1451.014676   3001.249474   460.989877   38.567093      0.0
# min       0.000000   9000.000000     3.197940    0.000000      0.0
# 25%     133.328269  10000.000000   173.379183   25.000000      0.0
# 50%     517.118528  11000.000000   233.202069   83.333300      0.0
# 75%    2557.634595  13000.000000   727.717582  100.000000      0.0
# max    4766.360515  30000.000000  6340.898794  100.000000      0.0

# %%
# sort the cluster numbers from min(0) to max(4)
sorted_clusters = sorted(df['cluster'].unique())

# select the rows of the same cluster number
# then get min/max income and average spending score
print("Cluster Income Ranges\n")
for cluster_num in sorted_clusters:
    small_df = df.loc[df['cluster'] == cluster_num]
    min_LIMIT = small_df['LIMIT'].min()
    max_LIMIT = small_df['LIMIT'].max()
    avg_score = small_df['Score'].mean()
    
    print(f"Cluster {cluster_num}: ${min_LIMIT}-{max_LIMIT}K, avg score: {int(avg_score)}")
# Out:
# Cluster Income Ranges
#
# Cluster 0: $9000.0-30000.0K, avg score: 63
# Cluster 1: $3500.0-9000.0K, avg score: 53
# Cluster 2: $1000.0-18000.0K, avg score: 48
# Cluster 3: $6500.0-30000.0K, avg score: 47
# Cluster 4: $50.0-4600.0K, avg score: 45

# %%
# new customer with Age=32, Income=$75K, and spending score=68
customer = [125, 4000, 200,75]

customer_group = kmeans.predict([customer])

print(f"Cluster assignment: {customer_group}")
# Out:
# Cluster assignment: [4]
